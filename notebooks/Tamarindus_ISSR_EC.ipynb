# %% [markdown]
# # FAIR ISSR Genetic Diversity Workflow – Tamarindus indica Germplasm
#
# This notebook provides a reproducible workflow for the full ISSR marker dataset derived from elite *Tamarindus indica* germplasm in Ecuador.
#
# ## Original Dataset Source
# Sarmiento L, Pérez-Almeida I, Díaz B, Álvarez H, Viera W. Molecular marker-based characterization of Ecuadorian dry forest tamarind plus trees. Bioagro. 2017;29(3):153–162. Available from: https://ve.scielo.org/scielo.php?script=sci_arttext&pid=S1316-33612017000300001. Accessed April 18, 2026.
#
# ## FAIR Data Note
# This workflow executes reproducible scripts for matrix construction, diversity analysis, clustering, and multivariate modeling.

# %% [markdown]
# # ============================================================
# # Reproducible ISSR Workflow – Tamarindus_ISSR_EC
# # ============================================================
# This notebook executes the full FAIR workflow from processed binary matrix and metadata files.

# %%
# 1. Load data
# !python /content/Tamarindus_ISSR_EC/scripts/01_load_issr_data.py

# %%
# 2. Calculate diversity metrics
# !python /content/Tamarindus_ISSR_EC/scripts/02_calculate_diversity_metrics.py

# %%
# 3. Jaccard distance and hierarchical clustering
# !python /content/Tamarindus_ISSR_EC/scripts/03_jaccard_distance_clustering.py

# %%
# 4. Multivariate analysis (PCA, t-SNE, PCoA, UMAP)
# !python /content/Tamarindus_ISSR_EC/scripts/04_multivariate_analysis.py

# %%
# 5. Generate figures
# !python /content/Tamarindus_ISSR_EC/scripts/05_generate_figures.py

# %%
# 6. Validate dataset structure and contents
# !python /content/Tamarindus_ISSR_EC/scripts/06_validate_dataset.py

# %%
# 7. Package repository for FAIR upload
# !python /content/Tamarindus_ISSR_EC/scripts/07_package_zip.py
